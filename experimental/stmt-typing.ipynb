# %%
from icecream import ic
help(compile)
# Out:
# Help on built-in function compile in module builtins:
#
# compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)
#     Compile source into a code object that can be executed by exec() or eval().
#
#     The source code may represent a Python module, statement or expression.
#     The filename will be used for run-time error messages.
#     The mode must be 'exec' to compile a module, 'single' to compile a
#     single (interactive) statement, or 'eval' to compile an expression.
#     The flags argument, if present, controls which future statements influence
#     the compilation of the code.
#     The dont_inherit argument, if true, stops the compilation inheriting
#     the effects of any future statements in effect in the code calling
#     compile; if absent or false these statements do influence the compilation,
#     in addition to any features explicitly specified.

# %%
import types
import ast
import inspect
import astpretty

class AnnotsToCommentsVisitor(ast.NodeTransformer):
    def visit_AnnAssign(self, node):
        node2 = ast.Assign([node.target], node.value, str(node.annotation))
        return ast.copy_location(node2, node)
  
class TypeCheckVisitor(ast.NodeTransformer):
    def visit_FunctionDef(self, node):
        # name is a raw string of the function name.
        # args is a arguments node.
        # body is the list of nodes inside the function.
        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).
        # returns is the return annotation (Python 3 only).
        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        
        node = self.generic_visit(node)
        new_decorator_list = [dec for dec in node.decorator_list 
                              if not (isinstance(dec, ast.Name) and dec.id == 'typecheck')]
        new_node = ast.FunctionDef(node.name + '_checked', node.args, 
                                   node.body, new_decorator_list, 
                                   node.returns, node.type_comment)
        new_node = ast.copy_location(new_node, node)
        return new_node
 

    def visit_AnnAssign(self, node):
        # An assignment with a type annotation. 
        # mode.target is a single node and can be a Name, a Attribute or a Subscript. 
        # annotation is the annotation, such as a Str or Name node. 
        # value is a single optional node.
        # simple is True for a Name node in target that do not appear in 
        #   between parenthesis and are hence pure names and not expressions.

        if not node.simple:
          return node
        
        assert isinstance(node.target, ast.Name) # Should be guaranteed by node.simple
        node_assert = ast.Assert(
          test=ast.Call(ast.Name('isinstance', ctx=ast.Load()), [
                          node.target, # ast.Name(node.target.id, ctx=ast.Load()), # Convert ctx from Store to Load 
                          node.annotation
                        ], 
                        []),
          msg=ast.Constant(value='failed', kind=None) # f'{node.target.id} not an {node.annotation}'
        )
        node_assert = ast.copy_location(node_assert, node)
        ast.fix_missing_locations(node_assert)
        return [node, node_assert]
  
def typecheck(f, show_src=False):
  # If this fails, try inspect-via-pytorch.py
  src = inspect.getsource(f)
  filename = inspect.getsourcefile(f)
  node = ast.parse(src, filename=filename)
  new_node = TypeCheckVisitor().visit(node)
  
  if show_src:
    print('typecheck: Transformed source code')
    new_src = ast.unparse(new_node)
    print(new_src)

  # Compile new AST to get wrapped function
  try:
    code = compile(new_node, filename='<typecheck>', mode='exec')
  except Exception as e:
    # Most compile errors are pretty opaque (https://stackoverflow.com/a/25795966)
    # So call astpretty.  If it succeeds, it's helpful to debug, if it fails, its
    # error messages are much more helpful
    msg = astpretty.pformat(new_node)
    print(msg)
    raise ValueError("See AST printed above") from e

  f_code = code.co_consts[3] # TODO search better
  f_checked = types.FunctionType(f_code, globals=f.__globals__)
  f_checked.__wrapped__ = f
  return f_checked


import jax
import jax.numpy as jnp

@typecheck
def foo(x : int, t : float) -> float:
  y : float = x * t
  assert isinstance(y, float), f"y a {type(y)} not a float"
  z : int = x // 2
  assert isinstance(z, int), "z not a int"
  return z * y

foo.__wrapped__(3,4.2)

foo(3,4.2)

@jax.jit
@typecheck
def foo1(x : int, t : jnp.ndarray) -> float:
  y : int = x *t # fred
  z : jnp.ndarray = y / 2
  return z
# Out:
# Module(
#     body=[
#         FunctionDef(
#             lineno=2,
#             col_offset=0,
#             end_lineno=7,
#             end_col_offset=14,
#             name='foo_checked',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[
#                     arg(
#                         lineno=2,
#                         col_offset=8,
#                         end_lineno=2,
#                         end_col_offset=15,
#                         arg='x',
#                         annotation=Name(lineno=2, col_offset=12, end_lineno=2, end_col_offset=15, id='int', ctx=Load()),
#                         type_comment=None,
#                     ),
#                     arg(
#                         lineno=2,
#                         col_offset=17,
#                         end_lineno=2,
#                         end_col_offset=26,
#                         arg='t',
#                         annotation=Name(lineno=2, col_offset=21, end_lineno=2, end_col_offset=26, id='float', ctx=Load()),
#                         type_comment=None,
#                     ),
#                 ],
#                 vararg=None,
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 kwarg=None,
#                 defaults=[],
#             ),
#             body=[
#                 AnnAssign(
#                     lineno=3,
#                     col_offset=2,
#                     end_lineno=3,
#                     end_col_offset=19,
#                     target=Name(lineno=3, col_offset=2, end_lineno=3, end_col_offset=3, id='y', ctx=Store()),
#                     annotation=Name(lineno=3, col_offset=6, end_lineno=3, end_col_offset=11, id='float', ctx=Load()),
#                     value=BinOp(
#                         lineno=3,
#                         col_offset=14,
#                         end_lineno=3,
#                         end_col_offset=19,
#                         left=Name(lineno=3, col_offset=14, end_lineno=3, end_col_offset=15, id='x', ctx=Load()),
#                         op=Mult(),
#                         right=Name(lineno=3, col_offset=18, end_lineno=3, end_col_offset=19, id='t', ctx=Load()),
#                     ),
#                     simple=1,
#                 ),
#                 Assert(
#                     lineno=3,
#                     col_offset=2,
#                     end_lineno=3,
#                     end_col_offset=19,
#                     test=Call(
#                         lineno=3,
#                         col_offset=2,
#                         end_lineno=3,
#                         end_col_offset=19,
#                         func=Name(lineno=3, col_offset=2, end_lineno=3, end_col_offset=19, id='isinstance', ctx=Load()),
#                         args=[
#                             Name(lineno=3, col_offset=2, end_lineno=3, end_col_offset=3, id='y', ctx=Store()),
#                             Name(lineno=3, col_offset=6, end_lineno=3, end_col_offset=11, id='float', ctx=Load()),
#                         ],
#                         keywords=[],
#                     ),
#                     msg=Constant(lineno=3, col_offset=2, end_lineno=3, end_col_offset=19, value='failed', kind=None),
#                 ),
#                 Assert(
#                     lineno=4,
#                     col_offset=2,
#                     end_lineno=4,
#                     end_col_offset=59,
#                     test=Call(
#                         lineno=4,
#                         col_offset=9,
#                         end_lineno=4,
#                         end_col_offset=29,
#                         func=Name(lineno=4, col_offset=9, end_lineno=4, end_col_offset=19, id='isinstance', ctx=Load()),
#                         args=[
#                             Name(lineno=4, col_offset=20, end_lineno=4, end_col_offset=21, id='y', ctx=Load()),
#                             Name(lineno=4, col_offset=23, end_lineno=4, end_col_offset=28, id='float', ctx=Load()),
#                         ],
#                         keywords=[],
#                     ),
#                     msg=JoinedStr(
#                         lineno=4,
#                         col_offset=31,
#                         end_lineno=4,
#                         end_col_offset=59,
#                         values=[
#                             Constant(lineno=4, col_offset=31, end_lineno=4, end_col_offset=59, value='y a ', kind=None),
#                             FormattedValue(
#                                 lineno=4,
#                                 col_offset=31,
#                                 end_lineno=4,
#                                 end_col_offset=59,
#                                 value=Call(
#                                     lineno=4,
#                                     col_offset=38,
#                                     end_lineno=4,
#                                     end_col_offset=45,
#                                     func=Name(lineno=4, col_offset=38, end_lineno=4, end_col_offset=42, id='type', ctx=Load()),
#                                     args=[Name(lineno=4, col_offset=43, end_lineno=4, end_col_offset=44, id='y', ctx=Load())],
#                                     keywords=[],
#                                 ),
#                                 conversion=-1,
#                                 format_spec=None,
#                             ),
#                             Constant(lineno=4, col_offset=31, end_lineno=4, end_col_offset=59, value=' not a float', kind=None),
#                         ],
#                     ),
#                 ),
#                 AnnAssign(
#                     lineno=5,
#                     col_offset=2,
#                     end_lineno=5,
#                     end_col_offset=18,
#                     target=Name(lineno=5, col_offset=2, end_lineno=5, end_col_offset=3, id='z', ctx=Store()),
#                     annotation=Name(lineno=5, col_offset=6, end_lineno=5, end_col_offset=9, id='int', ctx=Load()),
#                     value=BinOp(
#                         lineno=5,
#                         col_offset=12,
#                         end_lineno=5,
#                         end_col_offset=18,
#                         left=Name(lineno=5, col_offset=12, end_lineno=5, end_col_offset=13, id='x', ctx=Load()),
#                         op=FloorDiv(),
#                         right=Constant(lineno=5, col_offset=17, end_lineno=5, end_col_offset=18, value=2, kind=None),
#                     ),
#                     simple=1,
#                 ),
#                 Assert(
#                     lineno=5,
#                     col_offset=2,
#                     end_lineno=5,
#                     end_col_offset=18,
#                     test=Call(
#                         lineno=5,
#                         col_offset=2,
#                         end_lineno=5,
#                         end_col_offset=18,
#                         func=Name(lineno=5, col_offset=2, end_lineno=5, end_col_offset=18, id='isinstance', ctx=Load()),
#                         args=[
#                             Name(lineno=5, col_offset=2, end_lineno=5, end_col_offset=3, id='z', ctx=Store()),
#                             Name(lineno=5, col_offset=6, end_lineno=5, end_col_offset=9, id='int', ctx=Load()),
#                         ],
#                         keywords=[],
#                     ),
#                     msg=Constant(lineno=5, col_offset=2, end_lineno=5, end_col_offset=18, value='failed', kind=None),
#                 ),
#                 Assert(
#                     lineno=6,
#                     col_offset=2,
#                     end_lineno=6,
#                     end_col_offset=42,
#                     test=Call(
#                         lineno=6,
#                         col_offset=9,
#                         end_lineno=6,
#                         end_col_offset=27,
#                         func=Name(lineno=6, col_offset=9, end_lineno=6, end_col_offset=19, id='isinstance', ctx=Load()),
#                         args=[
#                             Name(lineno=6, col_offset=20, end_lineno=6, end_col_offset=21, id='z', ctx=Load()),
#                             Name(lineno=6, col_offset=23, end_lineno=6, end_col_offset=26, id='int', ctx=Load()),
#                         ],
#                         keywords=[],
#                     ),
#                     msg=Constant(lineno=6, col_offset=29, end_lineno=6, end_col_offset=42, value='z not a int', kind=None),
#                 ),
#                 Return(
#                     lineno=7,
#                     col_offset=2,
#                     end_lineno=7,
#                     end_col_offset=14,
#                     value=BinOp(
#                         lineno=7,
#                         col_offset=9,
#                         end_lineno=7,
#                         end_col_offset=14,
#                         left=Name(lineno=7, col_offset=9, end_lineno=7, end_col_offset=10, id='z', ctx=Load()),
#                         op=Mult(),
#                         right=Name(lineno=7, col_offset=13, end_lineno=7, end_col_offset=14, id='y', ctx=Load()),
#                     ),
#                 ),
#             ],
#             decorator_list=[],
#             returns=Name(lineno=2, col_offset=31, end_lineno=2, end_col_offset=36, id='float', ctx=Load()),
#             type_comment=None,
#         ),
#     ],
#     type_ignores=[],
# )
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb Cell 3 in typecheck(f, show_src)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=65'>66</a> try:
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=66'>67</a>   code = compile(new_node, filename='<typecheck>', mode='exec')
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=67'>68</a> except Exception as e:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=68'>69</a>   # Most compile errors are pretty opaque (https://stackoverflow.com/a/25795966)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=69'>70</a>   # So call astpretty.  If it succeeds, it's helpful to debug, if it fails, its
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=70'>71</a>   # error messages are much more helpful
#
# ValueError: expression must have Load context but has Store instead
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb Cell 3 in <cell line: 85>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=81'>82</a> import jax
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=82'>83</a> import jax.numpy as jnp
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=84'>85</a> @typecheck
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=85'>86</a> def foo(x : int, t : float) -> float:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=86'>87</a>   y : float = x * t
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=87'>88</a>   assert isinstance(y, float), f"y a {type(y)} not a float"
#
# /home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb Cell 3 in typecheck(f, show_src)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=71'>72</a>   msg = astpretty.pformat(new_node)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=72'>73</a>   print(msg)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=73'>74</a>   raise ValueError("See AST printed above") from e
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=75'>76</a> f_code = code.co_consts[3] # TODO search better
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/awf/dev/jax/jaxutils/experimental/stmt-typing.ipynb#ch0000002vscode-remote?line=76'>77</a> f_checked = types.FunctionType(f_code, globals=f.__globals__)
#
# ValueError: See AST printed above

# %%
x = 3
t
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t\n  z : jnp.ndarray = y / 2\n  return z\n\n# If this fails, try inspect-via-pytorch.py\nsrc = inspect.getsource(f)\nprint(src)\npy_ast = ast.parse(src)\nprint(ast.unparse(py_ast))\n\n\nfor n in ast.walk(py_ast):\n  print(n)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\n# If this fails, try inspect-via-pytorch.py\nsrc = inspect.getsource(f)\nprint(src)\npy_ast = ast.parse(src)\nprint(ast.unparse(py_ast))\n\n\nfor n in ast.walk(py_ast):\n  print(n)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\n# If this fails, try inspect-via-pytorch.py\nsrc = inspect.getsource(f)\nprint(src)\npy_ast = ast.parse(src)\n#print(ast.unparse(py_ast))\neval(py_ast)\n\n\nfor n in ast.walk(py_ast):\n  print(n)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  py_ast = ast.parse(src)\n  #print(ast.unparse(py_ast))\n  eval(py_ast)\n\n\n  for n in ast.walk(py_ast):\n    print(n)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  py_ast = ast.parse(src)\n  print(ast.unparse(py_ast))\n  eval(py_ast)\n\n\n  for n in ast.walk(py_ast):\n    print(n)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  py_ast = ast.parse(src)\n  print(ast.unparse(py_ast))\n  eval(ast.unparse(py_ast))\n\n\n  for n in ast.walk(py_ast):\n    print(n)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  py_ast = ast.parse(src)\n  print(ast.unparse(py_ast))\n  compile(py_ast)\n\n\n  for n in ast.walk(py_ast):\n    print(n)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def generic_visit(self, node):\n        ast.NodeVisitor.generic_visit(self, node)\n\n    def visit_GtE(self, node):\n        node2 = ast.Lt()\n        ast.copy_location(node2, node)\n        ast.NodeVisitor.generic_visit(self, node2)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z',
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def generic_visit(self, node):\n        ast.NodeVisitor.generic_visit(self, node)\n\n    def visit_Stmt(self, node):\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        ast.NodeVisitor.generic_visit(self, node2)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def generic_visit(self, node):\n        ast.NodeVisitor.generic_visit(self, node)\n\n    def visit_Stmt(self, node):\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        ast.NodeVisitor.generic_visit(self, node2)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  print(new_node)\n  new_src = ast.unparse(new_node)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def generic_visit(self, node):\n        ast.NodeVisitor.generic_visit(self, node)\n\n    def visit_Stmt(self, node):\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        ast.NodeVisitor.generic_visit(self, node2)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  print(node)\n  new_src = ast.unparse(new_node)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def generic_visit(self, node):\n        ast.NodeVisitor.generic_visit(self, node)\n\n    def visit_Stmt(self, node):\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        ast.NodeVisitor.generic_visit(self, node2)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  print(new_node)\n  new_src = ast.unparse(new_node)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_Stmt(self, node):\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        ast.NodeVisitor.generic_visit(self, node2)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  print(new_node)\n  new_src = ast.unparse(new_node)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_Stmt(self, node):\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        ast.NodeVisitor.generic_visit(self, node2)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(target, annotation, value, simple):\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        ast.NodeVisitor.generic_visit(self, node2)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, target, annotation, *, value, simple):\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n        print('Visit')\n        node2 = ast.Assert(True)\n        ast.copy_location(node2, node)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n        print('Visit')\n        #node2 = ast.Assert(True)\n        #ast.copy_location(node2, node)\n        return node\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n        print('Visit')\n        #node2 = ast.Assert(True)\n        #ast.copy_location(node2, node)\n        return node\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n        print('Visit')\n        node2 = ast.Assign(node.target, node.value, str(node.annotation))\n        #ast.copy_location(node2, node)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n        print('Visit')\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        #ast.copy_location(node2, node)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n        print('Visit', ast.dump(node))\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        print('Visit', ast.dump(node), ast.dump(node2))\n        #ast.copy_location(node2, node)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        print('Visit', ast.dump(node), ast.dump(node2))\n        #ast.copy_location(node2, node)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        print('Visit')\n        print('   it', ast.dump(node))\n        print('    t', ast.dump(node2))\n        #ast.copy_location(node2, node)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        node2 = ast.copy_location(node2, node)\n        print('Visit')\n        print('   it', ast.dump(node))\n        print('    t', ast.dump(node2))\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        node2 = ast.copy_location(node2, node)\n        print('Visit')\n        print('   it', ast.dump(node))\n        print('    t', ast.dump(node2))\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        node2 = ast.copy_location(node2, node)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\n\nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        node2 = ast.copy_location(node2, node)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z',
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nprint(ast.dump(ast.parse('isinstance(a, int)', mode='eval'), indent=4))\n\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assert([node.target], node.value, str(node.annotation))\n        node2 = ast.copy_location(node2, node)\n        return node2\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nprint(ast.dump(ast.parse('isinstance(a, int)', mode='eval'), indent=4))\n\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation])\n        )\n        node2 = ast.copy_location(node2, node)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nprint(ast.dump(ast.parse('isinstance(a, int)', mode='eval'), indent=4))\n\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        node2 = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation], [])\n        )\n        node2 = ast.copy_location(node2, node)\n        return [node, node2]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nprint(ast.dump(ast.parse('isinstance(a, int)', mode='eval'), indent=4))\n\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z",
#   "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nf(3,4)",
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name(\'isinstance\'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  exec(compile(new_node, filename="<ast>", mode="exec"))\n\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nf(3,4)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name(\'isinstance\'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  code = compile(new_node, filename="<ast>", mode="exec")\n\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nf(3,4)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name(\'isinstance\'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  #code = compile(new_node, filename="<ast>", mode="exec")\n  exec(new_src)\n\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nf(3,4)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_Function(self, node):\n        # name is a raw string of the function name.\n        # args is a arguments node.\n        # body is the list of nodes inside the function.\n        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).\n        # returns is the return annotation (Python 3 only).\n        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        \n        print(node.decorator_list)\n        return node # self.generic_visit(node)\n\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name(\'isinstance\'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  #code = compile(new_node, filename="<ast>", mode="exec")\n  exec(new_src)\n\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nf(3,4)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_Function(self, node):\n        # name is a raw string of the function name.\n        # args is a arguments node.\n        # body is the list of nodes inside the function.\n        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).\n        # returns is the return annotation (Python 3 only).\n        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        \n        print(node.decorator_list)\n        return node # self.generic_visit(node)\n\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name(\'isinstance\'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  #code = compile(new_node, filename="<ast>", mode="exec")\n  exec(new_src)\n\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nf(3,4)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_Function(self, node):\n        # name is a raw string of the function name.\n        # args is a arguments node.\n        # body is the list of nodes inside the function.\n        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).\n        # returns is the return annotation (Python 3 only).\n        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        \n        print(node.decorator_list)\n        return node # self.generic_visit(node)\n\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name(\'isinstance\'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  print(node.dump())\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  #code = compile(new_node, filename="<ast>", mode="exec")\n  exec(new_src)\n\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nf(3,4)',
#   'import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass Visitor(ast.NodeTransformer):\n    def visit_Function(self, node):\n        # name is a raw string of the function name.\n        # args is a arguments node.\n        # body is the list of nodes inside the function.\n        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).\n        # returns is the return annotation (Python 3 only).\n        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        \n        print(node.decorator_list)\n        return node # self.generic_visit(node)\n\n    def visit_AnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name(\'isinstance\'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nclass Fred:\n  def __instancecheck__(cls, obj):\n    return isinstance(obj, torch.Tensor)\n\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  print(src)\n  node = ast.parse(src)\n  print(ast.dump(node))\n  new_node = Visitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  #code = compile(new_node, filename="<ast>", mode="exec")\n  exec(new_src)\n\n\n@typecheck\ndef f(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nf(3,4)',
# ...
#  'x': <code object <module> at 0x7f4374a8fb50, file "/tmp/ipykernel_18161/16403658.py", line 1>,
#  '_i86': 'x',
#  '_86': <code object <module> at 0x7f4374e5ed90, file "/tmp/ipykernel_18161/1306866217.py", line 1>,
#  '_i87': 'dir(x)',
#  '_87': ['__class__',
#   '__delattr__',
#   '__dir__',
#   '__doc__',
#   '__eq__',
#   '__format__',
#   '__ge__',
#   '__getattribute__',
#   '__gt__',
#   '__hash__',
#   '__init__',
#   '__init_subclass__',
#   '__le__',
#   '__lt__',
#   '__ne__',
#   '__new__',
#   '__reduce__',
#   '__reduce_ex__',
#   '__repr__',
#   '__setattr__',
#   '__sizeof__',
#   '__str__',
#   '__subclasshook__',
#   'co_argcount',
#   'co_cellvars',
#   'co_code',
#   'co_consts',
#   'co_filename',
#   'co_firstlineno',
#   'co_flags',
#   'co_freevars',
#   'co_kwonlyargcount',
#   'co_lines',
#   'co_linetable',
#   'co_lnotab',
#   'co_name',
#   'co_names',
#   'co_nlocals',
#   'co_posonlyargcount',
#   'co_stacksize',
#   'co_varnames',
#   'replace'],
#  '_i88': 'x.foo',
#  '_i89': 'x.co_lines',
#  '_89': <function code.co_lines>,
#  '_i90': 'x.co_lines()',
#  '_90': <line_iterator at 0x7f4301220e40>,
#  '_i91': 'print(*x.co_lines())',
#  '_i92': 'x()',
#  '_i93': 'x.co_names',
#  '_93': ('jax', 'jit', 'int', 'jnp', 'ndarray', 'float', 'foo_checked'),
#  '_i94': 'x.co_code',
#  '_94': b'e\x00j\x01d\x00e\x02d\x01e\x03j\x04d\x02e\x05f\x06d\x03d\x04\x84\x04\x83\x01Z\x06d\x05S\x00',
#  '_i95': 'x.co_consts',
#  '_95': ('x',
#   't',
#   'return',
#   <code object foo_checked at 0x7f4374e5f470, file "/tmp/ipykernel_18161/1306866217.py", line 1>,
#   'foo_checked',
#   None),
#  '_i96': 'x.co_consts[3]',
#  '_96': <code object foo_checked at 0x7f4374e5f470, file "/tmp/ipykernel_18161/1306866217.py", line 1>,
#  '_i97': 'x.co_names',
#  '_97': ('jax', 'jit', 'int', 'jnp', 'ndarray', 'float', 'foo_checked'),
#  '_i98': 'print(x.co_names)',
#  '_i99': 'ic(x.co_names)',
#  '_99': ('jax', 'jit', 'int', 'jnp', 'ndarray', 'float', 'foo_checked'),
#  '_i100': 'ic(x.co_names)\nic(x.co_consts)',
#  '_100': ('x',
#   't',
#   'return',
#   <code object foo_checked at 0x7f4374e5f470, file "/tmp/ipykernel_18161/1306866217.py", line 1>,
#   'foo_checked',
#   None),
#  '_i101': 'ic(x.co_names)\nic(x.co_consts[3])',
#  '_101': <code object foo_checked at 0x7f4374e5f470, file "/tmp/ipykernel_18161/1306866217.py", line 1>,
#  '_i102': 'ic(x.co_names)\nic(x.co_consts[3])\n\nimport types\nf = types.Func',
#  'types': <module 'types' from '/home/awf/miniconda3/envs/jax/lib/python3.10/types.py'>,
#  '_i103': 'ic(x.co_names)\nic(x.co_consts[3])\n\nimport types\nf = types.FunctionType(x.co_consts[3], globals=foo.func_globals)',
#  '_i104': "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass TypeCheckVisitor(ast.NodeTransformer):\n    def visit_FunctionDef(self, node):\n        # name is a raw string of the function name.\n        # args is a arguments node.\n        # body is the list of nodes inside the function.\n        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).\n        # returns is the return annotation (Python 3 only).\n        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        \n        node = self.generic_visit(node)\n        new_decorator_list = [dec for dec in node.decorator_list \n                              if not (isinstance(dec, ast.Name) and dec.id == 'typecheck')]\n        for dec in new_decorator_list:\n          print(ast.dump(dec))\n        new_node = ast.FunctionDef(node.name + '_checked', node.args, \n                                   node.body, new_decorator_list, \n                                   node.returns, node.type_comment)\n        new_node = ast.copy_location(new_node, node)\n        return new_node\n \n\n    def visit_xAnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nx = 2\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  filename = inspect.getsourcefile(f)\n  print(src)\n  node = ast.parse(src, filename=filename)\n  new_node = TypeCheckVisitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  global x\n  x = compile(new_node, filename=filename, mode='exec')\n  ic(x.co_consts)\n  f = types.FunctionType(x.co_consts[3], globals=f.func_globals)\n\n  ic(f)\n  return f\n\n@jax.jit\n@typecheck\ndef foo(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nfoo(3,4)",
#  '_i105': "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass TypeCheckVisitor(ast.NodeTransformer):\n    def visit_FunctionDef(self, node):\n        # name is a raw string of the function name.\n        # args is a arguments node.\n        # body is the list of nodes inside the function.\n        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).\n        # returns is the return annotation (Python 3 only).\n        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        \n        node = self.generic_visit(node)\n        new_decorator_list = [dec for dec in node.decorator_list \n                              if not (isinstance(dec, ast.Name) and dec.id == 'typecheck')]\n        for dec in new_decorator_list:\n          print(ast.dump(dec))\n        new_node = ast.FunctionDef(node.name + '_checked', node.args, \n                                   node.body, new_decorator_list, \n                                   node.returns, node.type_comment)\n        new_node = ast.copy_location(new_node, node)\n        return new_node\n \n\n    def visit_xAnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nx = 2\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  filename = inspect.getsourcefile(f)\n  print(src)\n  node = ast.parse(src, filename=filename)\n  new_node = TypeCheckVisitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  global x\n  x = compile(new_node, filename=filename, mode='single')\n  ic(x.co_consts)\n  f = types.FunctionType(x.co_consts[3], globals=f.func_globals)\n\n  ic(f)\n  return f\n\n@jax.jit\n@typecheck\ndef foo(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nfoo(3,4)",
#  '_i106': "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass TypeCheckVisitor(ast.NodeTransformer):\n    def visit_FunctionDef(self, node):\n        # name is a raw string of the function name.\n        # args is a arguments node.\n        # body is the list of nodes inside the function.\n        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).\n        # returns is the return annotation (Python 3 only).\n        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        \n        node = self.generic_visit(node)\n        new_decorator_list = [dec for dec in node.decorator_list \n                              if not (isinstance(dec, ast.Name) and dec.id == 'typecheck')]\n        for dec in new_decorator_list:\n          print(ast.dump(dec))\n        new_node = ast.FunctionDef(node.name + '_checked', node.args, \n                                   node.body, new_decorator_list, \n                                   node.returns, node.type_comment)\n        new_node = ast.copy_location(new_node, node)\n        return new_node\n \n\n    def visit_xAnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nx = 2\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  filename = inspect.getsourcefile(f)\n  print(src)\n  node = ast.parse(src, filename=filename)\n  new_node = TypeCheckVisitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  global x\n  x = compile(new_node, filename=filename, mode='exec')\n  ic(x.co_consts)\n  f = types.FunctionType(x.co_consts[3], globals=f.func_globals)\n\n  ic(f)\n  return f\n\n@jax.jit\n@typecheck\ndef foo(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nfoo(3,4)",
#  '_i107': "import jax\nimport jax.numpy as jnp\n\nimport ast\nimport inspect\n\nclass AnnotsToCommentsVisitor(ast.NodeTransformer):\n    def visit_AnnAssign(self, node):\n        node2 = ast.Assign([node.target], node.value, str(node.annotation))\n        return ast.copy_location(node2, node)\n  \nclass TypeCheckVisitor(ast.NodeTransformer):\n    def visit_FunctionDef(self, node):\n        # name is a raw string of the function name.\n        # args is a arguments node.\n        # body is the list of nodes inside the function.\n        # decorator_list is the list of decorators to be applied, stored outermost first (i.e. the first in the list will be applied last).\n        # returns is the return annotation (Python 3 only).\n        # type_comment is optional. It is a string containing the PEP 484 type comment of the function (added in Python 3.8)        \n        node = self.generic_visit(node)\n        new_decorator_list = [dec for dec in node.decorator_list \n                              if not (isinstance(dec, ast.Name) and dec.id == 'typecheck')]\n        for dec in new_decorator_list:\n          print(ast.dump(dec))\n        new_node = ast.FunctionDef(node.name + '_checked', node.args, \n                                   node.body, new_decorator_list, \n                                   node.returns, node.type_comment)\n        new_node = ast.copy_location(new_node, node)\n        return new_node\n \n\n    def visit_xAnnAssign(self, node):\n        # An assignment with a type annotation. \n        # mode.target is a single node and can be a Name, a Attribute or a Subscript. \n        # annotation is the annotation, such as a Str or Name node. \n        # value is a single optional node.\n        # simple is True for a Name node in target that do not appear in \n        #   between parenthesis and are hence pure names and not expressions.\n\n        if not node.simple:\n          return node\n        \n        node_assert = ast.Assert(\n          ast.Call(ast.Name('isinstance'), [node.target, node.annotation], [])\n        )\n        node_assert = ast.copy_location(node_assert, node)\n        return [node, node_assert]\n  \nx = 2\ndef typecheck(f):\n  # If this fails, try inspect-via-pytorch.py\n  src = inspect.getsource(f)\n  filename = inspect.getsourcefile(f)\n  print(src)\n  node = ast.parse(src, filename=filename)\n  new_node = TypeCheckVisitor().visit(node)\n  new_src = ast.unparse(new_node)\n  print(new_src)\n  global x\n  x = compile(new_node, filename=filename, mode='exec')\n  ic(x)\n  ic(x.co_consts)\n  f = types.FunctionType(x.co_consts[3], globals=f.func_globals)\n\n  ic(f)\n  return f\n\n@jax.jit\n@typecheck\ndef foo(x : int, t : jnp.ndarray) -> float:\n  y : int = x *t # fred\n  z : jnp.ndarray = y / 2\n  return z\n\nfoo(3,4)",
#  '_i108': 'typecheck.__globals__'}
